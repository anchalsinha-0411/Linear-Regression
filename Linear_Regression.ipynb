# %% [markdown]
# <a href="https://colab.research.google.com/github/anchalsinha-0411/Linear-Regression/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Untitled folder/student_scores.csv')

# %%
df.shape
# Out:
# (25, 2)

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.tail()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.plot(x='Hours',y='Scores',style='o',figsize=(10,5),color='purple')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
print("training data",x_train)
print("testing data",x_test)
print("training data",y_train)
print("testing data",y_test) #ration wil be 80:20
# Out:
# training data [[3.8]
#  [1.9]
#  [7.8]
#  [6.9]
#  [1.1]
#  [5.1]
#  [7.7]
#  [3.3]
#  [8.3]
#  [9.2]
#  [6.1]
#  [3.5]
#  [2.7]
#  [5.5]
#  [2.7]
#  [8.5]
#  [2.5]
#  [4.8]
#  [8.9]
#  [4.5]]
# testing data [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]
# training data [35 24 86 76 17 47 85 42 81 88 67 30 25 60 30 75 21 54 95 41]
# testing data [20 27 69 30 62]
